# %%
from pathlib import Path
import pandas as pd
import xml.etree.ElementTree as ET
import logging
import json

data_json = "data/raw/acquiredco_api.json"
data_xml = "data/raw/benefits_enrollment.xml"
data_xlsx = "data/raw/payroll_data.xlsx"
data_csv = "data/raw/globaltech_hris.csv"

# %%
print("Pipeline module loaded successfully.")
# Out:
# Pipeline module loaded successfully.

# %%
df1 = pd.read_csv("data/raw/globaltech_hris.csv")

# %%
df1.head()
# Out:
#    employee_id first_name last_name                            email  \
# 0            1    Michael      King      michael.king@globaltech.com
# 1            2      David  Phillips    david.phillips@globaltech.com
# 2            3    Kenneth  Martinez  kenneth.martinez@globaltech.com
# 3            4       Paul    Cooper       paul.cooper@globaltech.com
# 4            5    Stephen    Parker    stephen.parker@globaltech.com
#
#         department              job_title   hire_date         country  \
# 0    Manufacturing           Data Analyst  2016-09-21     Netherlands
# 1         Strategy  Systems Administrator  2022-02-06           India
# 2  Human Resources       Business Analyst  2021-06-10  United Kingdom
# 3  Human Resources   Marketing Specialist  2024-09-07       Hong Kong
# 4        Marketing        Project Manager  2023-03-09           China
#
#   employment_type  manager_id
# 0       Full-Time     12765.0
# 1      Contractor      1662.0
# 2      Contractor      6142.0
# 3       Full-Time      5904.0
# 4       Part-Time       566.0

# %%
df1.shape
# Out:
# (15000, 10)

# %%
df1.describe()
# Out:
#         employee_id    manager_id
# count  15000.000000  13477.000000
# mean    7500.500000   7600.699711
# std     4330.271354   4287.127541
# min        1.000000     13.000000
# 25%     3750.750000   3928.000000
# 50%     7500.500000   7664.000000
# 75%    11250.250000  11122.000000
# max    15000.000000  14994.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_id      15000 non-null  int64
#  1   first_name       15000 non-null  object
#  2   last_name        15000 non-null  object
#  3   email            15000 non-null  object
#  4   department       14936 non-null  object
#  5   job_title        15000 non-null  object
#  6   hire_date        15000 non-null  object
#  7   country          14959 non-null  object
#  8   employment_type  15000 non-null  object
#  9   manager_id       13477 non-null  float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
df2 = pd.read_excel(data_xlsx)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19000 entries, 0 to 18999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   employee_id       19000 non-null  object
#  1   source            19000 non-null  object
#  2   base_salary       19000 non-null  object
#  3   currency          19000 non-null  object
#  4   pay_frequency     19000 non-null  object
#  5   bonus_target_pct  19000 non-null  float64
#  6   effective_date    19000 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.0+ MB

# %%
df2.describe()
# Out:
#        bonus_target_pct
# count      19000.000000
# mean          14.904974
# std            8.602993
# min            0.000000
# 25%            7.500000
# 50%           14.800000
# 75%           22.400000
# max           30.000000

# %%
df2.head(15)
# Out:
#    employee_id      source base_salary currency pay_frequency  \
# 0        14571  GlobalTech       77935      EUR       Monthly
# 1        12628  GlobalTech      119344      EUR     Bi-Weekly
# 2        12173  GlobalTech       67963      GBP        Annual
# 3         8747  GlobalTech      101292      EUR       Monthly
# 4         1729  GlobalTech       95986      GBP       Monthly
# 5         2090  GlobalTech       66510      EUR       Monthly
# 6        10713  GlobalTech      183156      GBP     Bi-Weekly
# 7         1575  GlobalTech       56061      USD        Annual
# 8        14994  GlobalTech      127207      USD        Annual
# 9          607  GlobalTech       73897      USD     Bi-Weekly
# 10       13793  GlobalTech      115433      GBP     Bi-Weekly
# 11       10286  GlobalTech      156520      USD       Monthly
# 12        7925  GlobalTech      118546      GBP     Bi-Weekly
# 13        8021  GlobalTech       87124      EUR        Annual
# 14        3826  GlobalTech      128108      EUR        Annual
#
#     bonus_target_pct effective_date
# 0               24.5     2023-05-12
# 1                2.8     2024-08-02
# 2                5.9     2023-10-12
# 3               17.9     2023-06-15
# 4               26.6     2023-06-28
# 5               23.4     2023-12-07
# 6               23.1     2023-10-01
# 7                0.7     2023-03-30
# 8               25.8     2023-12-06
# 9               15.6     2024-12-05
# 10               2.1     2024-05-21
# 11               5.7     2024-12-09
# 12               6.9     2024-09-12
# 13               5.7     2024-06-13
# 14              29.2     2024-12-03

# %%
pd.merge(df1, df2, on="employee_id")
# Out:
#       employee_id first_name last_name                           email  \
# 0               1    Michael      King     michael.king@globaltech.com
# 1               8      Linda    Thomas     linda.thomas@globaltech.com
# 2               8      Linda    Thomas     linda.thomas@globaltech.com
# 3               9      Scott   Kennedy    scott.kennedy@globaltech.com
# 4               9      Scott   Kennedy    scott.kennedy@globaltech.com
# ...           ...        ...       ...                             ...
# 13292       14995    Rebecca   Edwards  rebecca.edwards@globaltech.com
# 13293       14996   Patricia     Allen   patricia.allen@globaltech.com
# 13294       14996   Patricia     Allen   patricia.allen@globaltech.com
# 13295       15000      David      Knox       david.knox@globaltech.com
# 13296       15000      David      Knox       david.knox@globaltech.com
#
#             department          job_title   hire_date      country  \
# 0        Manufacturing       Data Analyst  2016-09-21  Netherlands
# 1        Manufacturing  Financial Analyst  2021-02-08        Japan
# 2        Manufacturing  Financial Analyst  2021-02-08        Japan
# 3      Human Resources      Data Engineer  2015-06-05       Canada
# 4      Human Resources      Data Engineer  2015-06-05       Canada
# ...                ...                ...         ...          ...
# 13292            Legal  Financial Analyst  2022-02-21       Canada
# 13293    Manufacturing            QA Lead  2021-05-09       Brazil
# 13294    Manufacturing            QA Lead  2021-05-09       Brazil
# 13295     Data Science         Accountant  2023-08-30       Sweden
# 13296     Data Science         Accountant  2023-08-30       Sweden
#
#       employment_type  manager_id      source base_salary currency  \
# 0           Full-Time     12765.0  GlobalTech       76645      EUR
# 1           Full-Time     11886.0  GlobalTech       53593      GBP
# 2           Full-Time     11886.0  GlobalTech      140400      USD
# 3           Full-Time         NaN  GlobalTech       86955      EUR
# 4           Full-Time         NaN  GlobalTech      105880      USD
# ...               ...         ...         ...         ...      ...
# 13292       Full-Time      2745.0  GlobalTech       89105      GBP
# 13293      Contractor      8563.0  GlobalTech      137991      USD
# 13294      Contractor      8563.0  GlobalTech       69238      GBP
# 13295      Contractor      8160.0  GlobalTech      195734      USD
# 13296      Contractor      8160.0  GlobalTech      145199      EUR
#
#       pay_frequency  bonus_target_pct effective_date
# 0         Bi-Weekly              14.8     2024-12-13
# 1         Bi-Weekly               1.9     2023-12-09
# 2            Annual               6.2     2023-07-09
# 3         Bi-Weekly              24.1     2023-07-27
# 4            Annual              27.7     2024-01-28
# ...             ...               ...            ...
# 13292       Monthly               2.2     2023-03-16
# 13293       Monthly               5.1     2024-10-15
# 13294     Bi-Weekly              14.1     2024-02-11
# 13295       Monthly              11.4     2023-08-06
# 13296     Bi-Weekly               1.2     2023-06-24
#
# [13297 rows x 16 columns]

# %%
pd.join(df1, df2, on="employee_id")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.join(df1, df2, on="employee_id")
#
# AttributeError: module 'pandas' has no attribute 'join'

# %%
df3 = pd.read_json(data_json)

# %%
df3.describe()
# Out:
#                            timestamp  total_records
# count                           3200         3200.0
# mean   2026-05-13 10:56:26.612362752         3200.0
# min       2026-05-13 10:56:26.612363         3200.0
# 25%    2026-05-13 10:56:26.612363008         3200.0
# 50%    2026-05-13 10:56:26.612363008         3200.0
# 75%    2026-05-13 10:56:26.612363008         3200.0
# max       2026-05-13 10:56:26.612363         3200.0
# std                              NaN            0.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status         3200 non-null   object
#  1   timestamp      3200 non-null   datetime64[ns]
#  2   total_records  3200 non-null   int64
#  3   employees      3200 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 100.1+ KB

# %%
df3.head(50)
# Out:
#      status                  timestamp  total_records  \
# 0   success 2026-05-13 10:56:26.612363           3200
# 1   success 2026-05-13 10:56:26.612363           3200
# 2   success 2026-05-13 10:56:26.612363           3200
# 3   success 2026-05-13 10:56:26.612363           3200
# 4   success 2026-05-13 10:56:26.612363           3200
# 5   success 2026-05-13 10:56:26.612363           3200
# 6   success 2026-05-13 10:56:26.612363           3200
# 7   success 2026-05-13 10:56:26.612363           3200
# 8   success 2026-05-13 10:56:26.612363           3200
# 9   success 2026-05-13 10:56:26.612363           3200
# 10  success 2026-05-13 10:56:26.612363           3200
# 11  success 2026-05-13 10:56:26.612363           3200
# 12  success 2026-05-13 10:56:26.612363           3200
# 13  success 2026-05-13 10:56:26.612363           3200
# 14  success 2026-05-13 10:56:26.612363           3200
# 15  success 2026-05-13 10:56:26.612363           3200
# 16  success 2026-05-13 10:56:26.612363           3200
# 17  success 2026-05-13 10:56:26.612363           3200
# 18  success 2026-05-13 10:56:26.612363           3200
# 19  success 2026-05-13 10:56:26.612363           3200
# 20  success 2026-05-13 10:56:26.612363           3200
# 21  success 2026-05-13 10:56:26.612363           3200
# 22  success 2026-05-13 10:56:26.612363           3200
# 23  success 2026-05-13 10:56:26.612363           3200
# 24  success 2026-05-13 10:56:26.612363           3200
# 25  success 2026-05-13 10:56:26.612363           3200
# 26  success 2026-05-13 10:56:26.612363           3200
# 27  success 2026-05-13 10:56:26.612363           3200
# 28  success 2026-05-13 10:56:26.612363           3200
# 29  success 2026-05-13 10:56:26.612363           3200
# 30  success 2026-05-13 10:56:26.612363           3200
# 31  success 2026-05-13 10:56:26.612363           3200
# 32  success 2026-05-13 10:56:26.612363           3200
# 33  success 2026-05-13 10:56:26.612363           3200
# 34  success 2026-05-13 10:56:26.612363           3200
# 35  success 2026-05-13 10:56:26.612363           3200
# 36  success 2026-05-13 10:56:26.612363           3200
# 37  success 2026-05-13 10:56:26.612363           3200
# 38  success 2026-05-13 10:56:26.612363           3200
# 39  success 2026-05-13 10:56:26.612363           3200
# 40  success 2026-05-13 10:56:26.612363           3200
# 41  success 2026-05-13 10:56:26.612363           3200
# 42  success 2026-05-13 10:56:26.612363           3200
# 43  success 2026-05-13 10:56:26.612363           3200
# 44  success 2026-05-13 10:56:26.612363           3200
# 45  success 2026-05-13 10:56:26.612363           3200
# 46  success 2026-05-13 10:56:26.612363           3200
# 47  success 2026-05-13 10:56:26.612363           3200
# 48  success 2026-05-13 10:56:26.612363           3200
# 49  success 2026-05-13 10:56:26.612363           3200
#
#                                             employees
# 0   {'employee_identifier': 'ACQ_00001', 'name': {...
# 1   {'employee_identifier': 'ACQ_00002', 'name': {...
# 2   {'employee_identifier': 'ACQ_00003', 'name': {...
# 3   {'employee_identifier': 'ACQ_00004', 'name': {...
# 4   {'employee_identifier': 'ACQ_00005', 'name': {...
# 5   {'employee_identifier': 'ACQ_00006', 'name': {...
# 6   {'employee_identifier': 'ACQ_00007', 'name': {...
# 7   {'employee_identifier': 'ACQ_00008', 'name': {...
# 8   {'employee_identifier': 'ACQ_00009', 'name': {...
# 9   {'employee_identifier': 'ACQ_00010', 'name': {...
# 10  {'employee_identifier': 'ACQ_00011', 'name': {...
# 11  {'employee_identifier': 'ACQ_00012', 'name': {...
# 12  {'employee_identifier': 'ACQ_00013', 'name': {...
# 13  {'employee_identifier': 'ACQ_00014', 'name': {...
# 14  {'employee_identifier': 'ACQ_00015', 'name': {...
# 15  {'employee_identifier': 'ACQ_00016', 'name': {...
# 16  {'employee_identifier': 'ACQ_00017', 'name': {...
# 17  {'employee_identifier': 'ACQ_00018', 'name': {...
# 18  {'employee_identifier': 'ACQ_00019', 'name': {...
# 19  {'employee_identifier': 'ACQ_00020', 'name': {...
# 20  {'employee_identifier': 'ACQ_00021', 'name': {...
# 21  {'employee_identifier': 'ACQ_00022', 'name': {...
# 22  {'employee_identifier': 'ACQ_00023', 'name': {...
# 23  {'employee_identifier': 'ACQ_00024', 'name': {...
# 24  {'employee_identifier': 'ACQ_00025', 'name': {...
# 25  {'employee_identifier': 'ACQ_00026', 'name': {...
# 26  {'employee_identifier': 'ACQ_00027', 'name': {...
# 27  {'employee_identifier': 'ACQ_00028', 'name': {...
# 28  {'employee_identifier': 'ACQ_00029', 'name': {...
# 29  {'employee_identifier': 'ACQ_00030', 'name': {...
# 30  {'employee_identifier': 'ACQ_00031', 'name': {...
# 31  {'employee_identifier': 'ACQ_00032', 'name': {...
# 32  {'employee_identifier': 'ACQ_00033', 'name': {...
# 33  {'employee_identifier': 'ACQ_00034', 'name': {...
# 34  {'employee_identifier': 'ACQ_00035', 'name': {...
# 35  {'employee_identifier': 'ACQ_00036', 'name': {...
# 36  {'employee_identifier': 'ACQ_00037', 'name': {...
# 37  {'employee_identifier': 'ACQ_00038', 'name': {...
# 38  {'employee_identifier': 'ACQ_00039', 'name': {...
# 39  {'employee_identifier': 'ACQ_00040', 'name': {...
# 40  {'employee_identifier': 'ACQ_00041', 'name': {...
# 41  {'employee_identifier': 'ACQ_00042', 'name': {...
# 42  {'employee_identifier': 'ACQ_00043', 'name': {...
# 43  {'employee_identifier': 'ACQ_00044', 'name': {...
# 44  {'employee_identifier': 'ACQ_00045', 'name': {...
# 45  {'employee_identifier': 'ACQ_00046', 'name': {...
# 46  {'employee_identifier': 'ACQ_00047', 'name': {...
# 47  {'employee_identifier': 'ACQ_00048', 'name': {...
# 48  {'employee_identifier': 'ACQ_00049', 'name': {...
# 49  {'employee_identifier': 'ACQ_00050', 'name': {...

# %%
print(df3.iloc[0])
# Out:
# status                                                     success
# timestamp                               2026-05-13 10:56:26.612363
# total_records                                                 3200
# employees        {'employee_identifier': 'ACQ_00001', 'name': {...
# Name: 0, dtype: object

# %%
def ingest_acquiredco_json(filepath: Path) -> pd.DataFrame:
    """
    Ingests AcquiredCo data from a JSON file.

    Args:
    filepath: Path to the JSON file.

    Returns:
    DataFrame containing the ingested data, or an empty DataFrame on error.
    """
    # try:
    logging.info(f"Ingesting AcquiredCo JSON: {filepath}")  
        
    raw_data = json.loads(filepath.read_text())
    employees = raw_data["employees"]
    extracted_employees = []
    page = 1
    start_idx = 0
    page_size = 1000
    total_records = len(employees)

    while start_idx < total_records:
        end_idx = start_idx + page_size
        page_data = employees[start_idx:end_idx]

        if not page_data:
            break   

        extracted_employees.extend(page_data)

        logging.info(f"Unpacked data up to row index {end_idx}")
        start_idx += page_size
        page += 1

    df = pd.json_normalize(extracted_employees, sep="_")
    df["source"] = "AcquiredCo JSON"  # Add source column for traceability

    logging.info(f"Successfully ingested AcquiredCo JSON: {filepath} with {len(df)} records")
    return df

    # except FileNotFoundError:
    #     logging.error(f"File not found: {filepath}")
    #     return pd.DataFrame()  # Return empty DataFrame on error        
    # except Exception as e:
    #     logging.error(f"Error ingesting JSON data: {e}")
    #     return pd.DataFrame()  # Return empty DataFrame on error

# %%
ingest_acquiredco_json(Path(data_json))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 ingest_acquiredco_json(Path(data_json))
#
# Cell In[36], line 23, in ingest_acquiredco_json(filepath)
#      21 while start_idx < total_records:
#      22     end_idx = start_idx + page_size
# ---> 23     page_data = raw_data[start_idx:end_idx]
#      25     if not page_data:
#      26         break
#
# TypeError: unhashable type: 'slice'

# %%
def ingest_acquiredco_json(filepath: Path) -> pd.DataFrame:
    """
    Ingests AcquiredCo data from a JSON file.

    Args:
    filepath: Path to the JSON file.

    Returns:
    DataFrame containing the ingested data, or an empty DataFrame on error.
    """
    logging.info(f"Ingesting AcquiredCo JSON: {filepath}")  
        
    raw_data = json.loads(filepath.read_text())
    employees = raw_data["employees"]
    extracted_employees = []
    page = 1
    start_idx = 0
    page_size = 1000
    total_records = len(employees)

    while start_idx < total_records:
        end_idx = start_idx + page_size
        page_data = employees[start_idx:end_idx]

        if not page_data:
            break   

        extracted_employees.extend(page_data)

        logging.info(f"Unpacked data up to row index {end_idx}")
        start_idx += page_size
        page += 1

    df = pd.json_normalize(extracted_employees, sep="_")
    df["source"] = "AcquiredCo JSON"

    logging.info(f"Successfully ingested AcquiredCo JSON: {filepath} with {len(df)} records")
    return df

result = ingest_acquiredco_json(Path(data_json))
print(result.shape)
result.head()
# Out:
# (3200, 13)
#   employee_identifier manager_employee_id name_first name_last  \
# 0           ACQ_00001           ACQ_02436      Larry     Smith
# 1           ACQ_00002           ACQ_02546    Michael  Crawford
# 2           ACQ_00003           ACQ_01415    Brandon     Moore
# 3           ACQ_00004           ACQ_01247     Ashley     Moore
# 4           ACQ_00005           ACQ_02354     Rachel     Clark
#
#           name_full                    contact_email assignment_department  \
# 0       Larry Smith       larry.smith@acquiredco.com               Product
# 1  Michael Crawford  michael.crawford@acquiredco.com                 Legal
# 2     Brandon Moore     brandon.moore@acquiredco.com             Marketing
# 3      Ashley Moore      ashley.moore@acquiredco.com             Marketing
# 4      Rachel Clark      rachel.clark@acquiredco.com                 Sales
#
#        assignment_role assignment_location assignment_hire_timestamp  \
# 0           Controller              Mexico       2024-06-27T00:00:00
# 1           Controller               Japan       2021-06-09T00:00:00
# 2  Solutions Architect       United States       2022-06-20T00:00:00
# 3      Product Manager         Netherlands       2022-04-27T00:00:00
# 4  Solutions Architect              France       2017-05-01T00:00:00
#
#   employment_type employment_status           source
# 0              PT            Active  AcquiredCo JSON
# 1              PT          Inactive  AcquiredCo JSON
# 2      CONTRACTOR          On Leave  AcquiredCo JSON
# 3      CONTRACTOR          On Leave  AcquiredCo JSON
# 4              PT            Active  AcquiredCo JSON

# %%
df4 = ET.parse(data_xml)
root = df4.getroot()
print(root.tag)  # Print the root tag to verify successful parsing

for i, record in enumerate(root[:2]):  # Slices the first two child elements
    print(f"\nRecord {i} Tag: {record.tag}")
    
    # Print out all the field tags and data inside this record
    for field in record:
        print(f"  Field: <{field.tag}> -> Value: {field.text}")
# Out:
# benefits_enrollments
#
# Record 0 Tag: enrollment
#   Field: <employee_id> -> Value: 2239
#   Field: <plan_type> -> Value: Vision
#   Field: <coverage_level> -> Value: Family
#   Field: <enrollment_date> -> Value: 2024-03-23
#   Field: <premium_employee> -> Value: 54.5
#   Field: <premium_employer> -> Value: 469.17
#
# Record 1 Tag: enrollment
#   Field: <employee_id> -> Value: 7612
#   Field: <plan_type> -> Value: 401(k)
#   Field: <coverage_level> -> Value: Employee+Spouse
#   Field: <enrollment_date> -> Value: 2021-06-14
#   Field: <premium_employee> -> Value: 188.19
#   Field: <premium_employer> -> Value: 705.57

# %%
records = []

for employee in root.findall("enrollment"):
    record = {
        "employee_id": employee.findtext("employee_id"),
        "plan_type": employee.findtext("plan_type"),
        "coverage_level": employee.findtext("coverage_level"),
        "enrollment_date": employee.findtext("enrollment_date"),
        "premium_employee": employee.findtext("premium_employee"),
        "premium_employer": employee.findtext("premium_employer"),
        "source": "Benefits XML"  # Add source for traceability
    }
    records.append(record)

df = pd.DataFrame(records)
df["enrollment_date"] = pd.to_datetime(df["enrollment_date"], errors="coerce")
df["employee_id"] = df["employee_id"].astype(str)
df["plan_type"] = df["plan_type"].astype(str)

# %%
import unicodedata
import pandas as pd

def normalize_name_series(series: pd.Series) -> pd.Series:
    """
    Standardizes a Pandas Series of names: normalizes Unicode, 
    strips whitespace, and applies Title Case safely.
    """
    # 1. Drop missing values safely and force to string
    series = series.fillna("").astype(str).str.strip()
    
    # 2. Unicode normalization (NFC form unifies accented characters)
    # We use a lambda to apply Python's native unicodedata to every text element
    series = series.apply(lambda x: unicodedata.normalize("NFC", x))
    
    # 3. Title case standardization
    # Note: Python's .str.title() can mangle "O'Brien" into "O'brien".
    # Using .str.capitalize() or strict regex/builtin styling handles multi-word names cleaner.
    series = series.str.title() 
    
    return series

# %%
import pandas as pd

def generate_namespaced_id(series: pd.Series, prefix: str) -> pd.Series:
    """
    Resolves ID overlaps by padding numeric identifiers to 6 digits 
    and prepending a company-specific namespace prefix.

    Args:
        series (pd.Series): A Pandas Series containing raw employee IDs 
                            as strings, floats, or integers.
        prefix (str): The company prefix to prepend (e.g., "GT-" or "AC-").

    Returns:
        pd.Series: A standard string Series formatted as 'PREFIX-000000'.
                   Missing values or NaNs are preserved as empty strings.
    """
    # 1. Handle missing values, convert to float string removal if needed
    # If IDs came in as floats (like 1042.0), strip the decimal point
    sanitized = series.fillna("").astype(str).str.replace(r"\.0$", "", regex=True).str.strip()
    
    # 2. Filter out empty records so we don't accidentally create "GT-000000" for blank rows
    mask = (sanitized != "") & (sanitized != "nan")
    
    # 3. Apply your zfill strategy and prepend the namespace prefix
    padded_series = pd.Series("", index=series.index)
    padded_series[mask] = prefix + sanitized[mask].str.zfill(6)
    
    return padded_series

# %%
print
